# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'C:/Users/admin/Desktop/Israth/Iris.csv'
iris_df = pd.read_csv(file_path)
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
avg_measurements = iris_df.groupby('Species').mean().drop(columns=['Id'])

# %%
colors = {'setosa': 'blue', 'versicolor': 'green', 'virginica': 'purple'}

# %%
avg_measurements.plot(kind='bar', figsize=(12, 8))
plt.title('Average Measurements per Species')
plt.xlabel('Species')
plt.ylabel('Measurements (cm)')
plt.xticks(rotation=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=iris_df, x='SepalLengthCm', y='SepalWidthCm', hue='Species', palette='Set1')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.show()

# %%
plt.figure(figsize=(12, ))
sns.boxplot(data=iris_df, x='Species', y='SepalLengthCm', palette='Set3')
plt.title('Box Plot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()
